# %% [markdown]
# # Aula 1

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  str
#  2   employment_type     133349 non-null  str
#  3   job_title           133349 non-null  str
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  str
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  str
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  str
#  10  company_size        133349 non-null  str
# dtypes: float64(1), int64(3), str(7)
# memory usage: 11.2 MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print(f"O DataFrame possui {linhas} linhas e {colunas} colunas.")
# Out:
# O DataFrame possui 133349 linhas e 11 colunas.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='str')

# %%
df.rename(columns={
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}, inplace=True)

df.columns
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='str')

# %%
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
def_senioridade = {
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

df['senioridade'] = df['senioridade'].replace(def_senioridade)
df['senioridade'].value_counts()
# Out:
# senioridade
# Sênior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
def_contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Meio Período',
    'FL': 'Freelancer'
}

df['contrato'] = df['contrato'].replace(def_contrato)
df['contrato'].value_counts()
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Meio Período         376
# Freelancer            16
# Name: count, dtype: int64

# %%
def_tamanho_empresa = {
    'M': 'Média',
    'L': 'Grande',
    'S': 'Pequena'
}

df['tamanho_empresa'] = df['tamanho_empresa'].replace(def_tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# Média      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
def_remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

df['remoto'] = df['remoto'].replace(def_remoto)
df['remoto'].value_counts()
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.describe(include='all')
# Out:
#                   ano senioridade        contrato           cargo  \
# count   133339.000000      133349          133349          133349
# unique            NaN           4               4             390
# top               NaN      Sênior  Tempo Integral  Data Scientist
# freq              NaN       77241          132563           17314
# mean      2024.358770         NaN             NaN             NaN
# std          0.680627         NaN             NaN             NaN
# min       2020.000000         NaN             NaN             NaN
# 25%       2024.000000         NaN             NaN             NaN
# 50%       2024.000000         NaN             NaN             NaN
# 75%       2025.000000         NaN             NaN             NaN
# max       2025.000000         NaN             NaN             NaN
#
#              salario   moeda            usd residencia      remoto empresa  \
# count   1.333490e+05  133349  133349.000000     133349      133349  133349
# ...

# %% [markdown]
# # Aula 2 - Limpeza de dados

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade        contrato                      cargo  salario  \
# 5588    NaN      Sênior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Sênior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Sênior  Tempo Integral                   Engineer   112000
# 131000  NaN      Sênior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Sênior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %% [markdown]
# ## Criando DFs para entender novos conceitos

# %%
import numpy as np

#Criando um novo DF para entender o fillna -> media -> mediana

df_salarios = pd.DataFrame({

    'nome':["ana", "bruno", "carla", "daniel", "edson"],
    'salario' : [4000, np.nan, 5000, np.nan, 100000]

})

df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#      nome   salario  salario_media  salario_mediana
# 0     ana    4000.0        4000.00           4000.0
# 1   bruno       NaN       36333.33           5000.0
# 2   carla    5000.0        5000.00           5000.0
# 3  daniel       NaN       36333.33           5000.0
# 4   edson  100000.0      100000.00         100000.0

# %%
#Novo DF pra entender o ffil (forward fill = completa null com o valor anterior)

df_temperaturas = pd.DataFrame({

    'dia':['seg','ter','qua', 'qui', 'sex'],
    'temperatura':[30, np.nan, np.nan, 28, 27]

})

df_temperaturas['preenchido_ffill'] = df_temperaturas['temperatura'].ffill()
df_temperaturas
# Out:
#    dia  temperatura  preenchido_ffill
# 0  seg         30.0              30.0
# 1  ter          NaN              30.0
# 2  qua          NaN              30.0
# 3  qui         28.0              28.0
# 4  sex         27.0              27.0

# %%
#Novo DF pra entender o bfil (backward fill = completa null com o valor posterior)

df_temperaturas = pd.DataFrame({

    'dia':['seg','ter','qua', 'qui', 'sex'],
    'temperatura':[30, np.nan, np.nan, 28, 27]

})

df_temperaturas['preenchido_bfill'] = df_temperaturas['temperatura'].bfill()
df_temperaturas
# Out:
#    dia  temperatura  preenchido_bfill
# 0  seg         30.0              30.0
# 1  ter          NaN              28.0
# 2  qua          NaN              28.0
# 3  qui         28.0              28.0
# 4  sex         27.0              27.0

# %%
#Novo DF pra entender fillna com valor específico

df_cidades = pd.DataFrame({

    'nome':["ana", "bruno", "carla", "daniel", "edson"],
    'cidade':['sao paulo', np.nan, 'curitiba', np.nan, 'belem']
    
})

df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna('não informado')
df_cidades
# Out:
#      nome     cidade cidade_preenchida
# 0     ana  sao paulo         sao paulo
# 1   bruno        NaN     não informado
# 2   carla   curitiba          curitiba
# 3  daniel        NaN     não informado
# 4   edson      belem             belem

# %% [markdown]
# ## De volta ao DF

# %%
#Dropar as linhas sem informação
df_limpo = df.dropna()

df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))
df_limpo.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  int64
#  1   senioridade      133339 non-null  str
#  2   contrato         133339 non-null  str
#  3   cargo            133339 non-null  str
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  str
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  str
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  str
#  10  tamanho_empresa  133339 non-null  str
# dtypes: int64(3), object(1), str(7)
# memory usage: 12.2+ MB

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Média
# 1  136000         US      Remoto      US           Média
# 2  158800         AU  Presencial      AU           Média
# 3  139200         AU  Presencial      AU           Média
# 4   90000         US  Presencial      US           Média

# %% [markdown]
# # Aula 3

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar',title='Distribuição de senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data = df_limpo, x='senioridade', y='usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = df_limpo, x='senioridade', y='usd')
plt.title('Salário anual por nível de senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário')
plt.show()

# %%
#Calculo da média do salário pra cada senioridade do maior pro menor
df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# Executivo    202027.667813
# Sênior       172850.838301
# Pleno        143044.845979
# Júnior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index
ordem
# Out:
# Index(['Júnior', 'Pleno', 'Sênior', 'Executivo'], dtype='str', name='senioridade')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = df_limpo, x='senioridade', y='usd', order=ordem)
plt.title('Salário anual por nível de senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df_limpo['usd'],bins=50, kde=True)
plt.title('Distribuição dos salários anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_limpo['usd'])
plt.title('Boxplot salário')
plt.xlabel('Salário em USD')
plt.show()

# %%
ordem_senioridade = ['Júnior','Pleno','Sênior','Executivo']
plt.figure(figsize=(8,8))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade)
plt.title('Distribuição salarial por senioridade')
plt.xlabel('Senioridade')
plt.show()

# %%
ordem_senioridade = ['Júnior','Pleno','Sênior','Executivo']
plt.figure(figsize=(8,8))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade, palette='Set2', hue='senioridade')
plt.title('Distribuição salarial por senioridade')
plt.xlabel('Senioridade')
plt.show()

# %%
import plotly.express as px

# %%
senioridade_media_salario = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).reset_index()

# %%
fig = px.bar(senioridade_media_salario, 
             x='senioridade', 
             y='usd',
             title='Média Salarial por Senioridade',
             labels={'usd': 'Salário anual (USD)', 'senioridade': 'Senioridade'},
             category_orders={'senioridade': ordem_senioridade})
fig.show()

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
remoto_contagem
# Out:
#   tipo_trabalho  quantidade
# 0    Presencial      105305
# 1        Remoto       27716
# 2       Híbrido         318

# %%
fig = px.pie(remoto_contagem, 
             names='tipo_trabalho', 
             values='quantidade',
             title='Proporção de modalidades de trabalho'
             )
fig.show()

# %%
fig = px.pie(remoto_contagem, 
             names='tipo_trabalho', 
             values='quantidade',
             title='Proporção de modalidades de trabalho',
             hole=0.5
             )
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Desafio

# %% [markdown]
# Desafio: Visualização de salário médio por país pro cargo cientista de dados usando o plotly

# %%
df_limpo.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Média
# 1  136000         US      Remoto      US           Média
# 2  158800         AU  Presencial      AU           Média
# 3  139200         AU  Presencial      AU           Média
# 4   90000         US  Presencial      US           Média

# %%
#Criar DF com os dados para o gráfico
df_desafio = df_limpo[['residencia', 'cargo','usd']]
df_desafio_media = df_desafio.groupby(['residencia', 'cargo'])['usd'].mean().sort_values(ascending=False).reset_index()
df_desafio_media.head()
# Out:
#   residencia                          cargo            usd
# 0         GB     ML Infrastructure Engineer  465625.000000
# 1         US             Research Team Lead  450000.000000
# 2         CA                   AI Architect  437266.666667
# 3         IL                   AI Scientist  417937.000000
# 4         GB  Analytics Engineering Manager  399880.000000

# %%
#Criar filtro
filtro = df_desafio_media.loc[df_desafio_media['cargo']=='Data Scientist']
filtro.head()
# Out:
#     residencia           cargo            usd
# 215         US  Data Scientist  162802.494603
# 268         SG  Data Scientist  152522.714286
# 269         BG  Data Scientist  152500.000000
# 270         CH  Data Scientist  152256.666667
# 338         EG  Data Scientist  140690.909091

# %%
#Gráfico
fig = px.bar(filtro,
             x='residencia', 
             y='usd',
             title='Média Salarial por País',
             labels={'usd': 'Média salarial (USD)', 'residencia': 'País'}
)
fig.show()

# %% [markdown]
# # Aula 4

# %% [markdown]
# Correção do desafio

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 24.0 MB/s  0:00:00m0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pycountry

#Utilizar o pycountry pra alterar o nome dos países
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

#Criar coluna com novos nomes
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

#Calcular média por país
df_ds = df_limpo[df_limpo['cargo']=='Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

#Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário para cientista de dados por país',
                    labels={'usd':'Salário Médio (USD)', 'residencia_iso3':'País'}
)

fig.show()

# %%
#Criar arquivo com o dataframe
df_limpo.to_csv('dados-imersao-final.csv', index=False)
